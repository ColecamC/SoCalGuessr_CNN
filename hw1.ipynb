# %%
def one_year(c, t):
    return 0.95*c + 0.03*t, 0.05*c + 0.97*t

# %%
c , t = 600, 400
for _ in range(50):
    c, t = one_year(c, t)
print(f"c = {c}, t = {t}")
# Out:
# c = 378.47995706216415, t = 621.5200429378342
